# %%
import pandas as pd
import subprocess
import os
# %matplotlib inline
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px

# %%
url="https://covid.ourworldindata.org/data/owid-covid-data.csv"  #Extract data from URL
data = pd.read_csv(url) #Reading extracted data from URL
data.head() #Display first 5 rows of the data
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
GER = data[data['location'] == 'Germany'].reset_index(drop=True)  #Extract data of three countries in three variables
CZE = data[data['location'] == 'Czechia'].reset_index(drop=True)
FRA = data[data['location'] == 'France'].reset_index(drop=True)

# %%
GER['cases_per_population'] = GER['total_cases']/GER['population'] #Calculate the absolute Covid cases/population
GER ['Vaccine_percentage'] = GER['people_vaccinated']*100/GER['population'] #Calculate the vaccination percentage

# %%
CZE['cases_per_population'] = CZE['total_cases']/CZE['population'] #Calculate the absolute Covid cases/population
CZE['Vaccine_percentage'] = CZE['people_vaccinated']*100/CZE['population'] #Calculate the vaccination percentage

# %%
FRA['cases_per_population'] = FRA['total_cases']/FRA['population'] #Calculate the absolute Covid cases/population
FRA ['Vaccine_percentage'] = FRA['people_vaccinated']*100/FRA['population'] #Calculate the vaccination percentage

# %%
combined_list = pd.concat([GER,CZE,FRA]) #Make combined list of all countries to display

# %%
fig = px.line(combined_list,x = "date",y = "cases_per_population", title = "COVID cases", color = 'location') #Plotting
fig.show()
# Out:
# <div>                            <div id="9a0e4e52-e7d7-46e5-893a-1cd777a01bd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a0e4e52-e7d7-46e5-893a-1cd777a01bd4")) {                    Plotly.newPlot(                        "9a0e4e52-e7d7-46e5-893a-1cd777a01bd4",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>cases_per_population=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","20
# ...

# %%
fig = px.line(combined_list,x = "date",y = "Vaccine_percentage", title = "COVID vaccination percentage", color = 'location')
fig.show()
# Out:
# <div>                            <div id="a3c598b4-3a1c-47a6-9264-4d1ae291babf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3c598b4-3a1c-47a6-9264-4d1ae291babf")) {                    Plotly.newPlot(                        "a3c598b4-3a1c-47a6-9264-4d1ae291babf",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>Vaccine_percentage=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020
# ...
